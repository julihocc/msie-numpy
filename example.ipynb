# %%
import matplotlib.pyplot as plt 
import numpy as np 

# input 

def f(x): 
    return x**3-x-2 

a = 1
b = 2 
tol = 0.001 
nmax = 1000 

x_range = np.linspace(a,b,num=101) 
# print(x_range)
# print(len(x_range))
y_range = f(x_range)
plt.plot(x_range,y_range)
plt.show()
